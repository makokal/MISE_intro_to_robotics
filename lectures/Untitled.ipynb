# %%
import cv2 as cv
import numpy as np

from matplotlib import pyplot as plt

# %%
left = cv.imread('../projects/democv/Couch-perfect/im0.png')
right = cv.imread('../projects/democv/Couch-perfect/im1.png')

# %%
plt.imshow(left[:, :, ::-1])

# %%
plt.imshow(right[:, :, ::-1])

# %%
def scale(img, s=2):
    img = cv.resize(img, None, fx=s, fy=s)
    return img

# %%
scaled_left = scale(left, 4)

# %%
def add(x, y):
    return x+y

# %%
import dis

# %%
dis.dis(add)
# Out:
#   2           0 LOAD_FAST                0 (x)
#               2 LOAD_FAST                1 (y)
#               4 BINARY_ADD
#               6 RETURN_VALUE

# %%
cv.STEREO_

# %%
left_gray = cv.cvtColor(left,cv.COLOR_BGR2GRAY)
right_gray = cv.cvtColor(right,cv.COLOR_BGR2GRAY)

# %%
left_gray.shape, left.shape
# Out:
# ((1992, 2300), (1992, 2300, 3))

# %%
plt.imshow(left_gray, cmap='gray')

# %%
disparity = left_gray - right_gray

# %%
plt.imshow(left[:, :, ::-1])

# %%
plt.imshow(disparity, cmap='plasma')
plt.colorbar()

# %%
plt.plot(disparity[1000, ::100])

# %%
plt.plot(disparity[::100, 500])

# %%
x = np.random.random((40, 40))

# %%
plt.imshow(x, cmap='gray')
plt.colorbar()

# %% [markdown]
# # Homography Projections
#
# $$ H = \begin{bmatrix} a & b & c\\d & e & f\\g & h & i \end{bmatrix} $$

# %%
A = np.array([[1,2],[2,3],[5,6]])
B = np.array([[1,2, 4],[2,3, 2],[5,6, 2]])
B
# Out:
# array([[1, 2, 4],
#        [2, 3, 2],
#        [5, 6, 2]])

# %%
np.invert(B)
# Out:
# array([[-2, -3, -5],
#        [-3, -4, -3],
#        [-6, -7, -3]])

# %%
np.invert(A[:, 1])
# Out:
# array([-3, -4, -7])

# %%
cv.findHomography?
# Out:
# Docstring:
# findHomography(srcPoints, dstPoints[, method[, ransacReprojThreshold[, mask[, maxIters[, confidence]]]]]) -> retval, mask
# .   @brief Finds a perspective transformation between two planes.
# .
# .   @param srcPoints Coordinates of the points in the original plane, a matrix of the type CV_32FC2
# .   or vector\<Point2f\> .
# .   @param dstPoints Coordinates of the points in the target plane, a matrix of the type CV_32FC2 or
# .   a vector\<Point2f\> .
# .   @param method Method used to compute a homography matrix. The following methods are possible:
# .   -   **0** - a regular method using all the points, i.e., the least squares method
# .   -   **RANSAC** - RANSAC-based robust method
# .   -   **LMEDS** - Least-Median robust method
# .   -   **RHO** - PROSAC-based robust method
# .   @param ransacReprojThreshold Maximum allowed reprojection error to treat a point pair as an inlier
# .   (used in the RANSAC and RHO methods only). That is, if
# ...

# %%
from cv2 import Feature2D

# %%
ff = Feature2D()

# %%
ff.detect(left_gray)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-8f5db3dfff15> in <module>()
# ----> 1 ff.detect(left_gray)
#
# TypeError: Incorrect type of self (must be 'Feature2D' or its derivative)
